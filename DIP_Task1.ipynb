# %% [markdown]
# <a href="https://colab.research.google.com/github/Haniaakanwal/DIP-TASK/blob/main/DIP_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Upload image
uploaded = files.upload()
image_name = list(uploaded.keys())[0]

# Read image
img = cv2.imread(image_name)

# Convert BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Create empty channels
zeros = np.zeros_like(img_rgb[:, :, 0])

# Separate RGB components as color images
red_img = cv2.merge([img_rgb[:, :, 0], zeros, zeros])
green_img = cv2.merge([zeros, img_rgb[:, :, 1], zeros])
blue_img = cv2.merge([zeros, zeros, img_rgb[:, :, 2]])

# Convert to Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert to Binary
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Display images
plt.figure(figsize=(12, 8))

plt.subplot(2, 3, 1)
plt.title("Original Image")
plt.imshow(img_rgb)
plt.axis('off')

plt.subplot(2, 3, 2)
plt.title("Red Component")
plt.imshow(red_img)
plt.axis('off')

plt.subplot(2, 3, 3)
plt.title("Green Component")
plt.imshow(green_img)
plt.axis('off')

plt.subplot(2, 3, 4)
plt.title("Blue Component")
plt.imshow(blue_img)
plt.axis('off')

plt.subplot(2, 3, 5)
plt.title("Grayscale Image")
plt.imshow(gray, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 6)
plt.title("Binary Image")
plt.imshow(binary, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-48966308-d3f8-4143-b1f2-4404609c05ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48966308-d3f8-4143-b1f2-4404609c05ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
